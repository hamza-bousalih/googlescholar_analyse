# %%
import json, copy, re
import pandas as pd

# %%
with open("uca.json", 'r') as file:
    data = json.load(file)
    
profiles = copy.deepcopy(data)
articles_data = copy.deepcopy(data)

# %% [markdown]
# # Transform profile Data

# %% [markdown]
# #### Transform the `Article` and `Spciality`

# %%
for item in profiles:
    item["Spciality"] = ", ".join(item["Spciality"])
    item["Article"] = len(item["Article"])

# %% [markdown]
# #### Add 'Faculty'

# %%
class Transform:
    def __init__(self, to, test) -> None:
        self.value = to
        self.test = test


def test(e, search):
    return any(s.lower() in e.lower() for s in search)


def transform_to_fstg(e):
    return test(e, ["FST", "FSTG", "Faculty of Sciences and Techniques", "Faculté des Sciences et Techniques"])


def transform_to_ensa(e):
    return test(e, ["ENSA"])


def transform_to_fssm(e):
    return test(e, ["FSSM", "Semlalia", "Faculty of Sciences"])


def transform_to_other(e):
    return e == "Université Cadi Ayyad" or e == "CADI AYYAD UNIVERSITY"
    # return test(e, ["Université Cadi Ayyad", "Cadi Ayyad University", " Cadi  Ayyad"])


faculties_transform = [
    Transform("FSTG", transform_to_fstg),
    Transform("ENSA", transform_to_ensa),
    Transform("FSSM", transform_to_fssm),
    Transform("Other", transform_to_other),
]


def transform_faculties(data):
    for ind, item in enumerate(data):
        for transform in faculties_transform:
            if transform.test(item.get("ASS - Unevercity", "")):
                data[ind]["faculty"] = transform.value
                break
            else: data[ind]["faculty"] = item.get("ASS - Unevercity")
            # else: data[ind]["faculty"] = "None"

# %%
# from faculty_transform import transform_faculties
profiles = copy.deepcopy(profiles)
transform_faculties(profiles)

# %%
# for prof in profiles:
#     print(prof["faculty"])

# %%
profiles_df = pd.DataFrame(profiles)
profiles_df
# Out:
#               Nom et Prénom  \
# 0             salah er-raki
# 1     Abdelkader Outzourhit
# 2             Jamal Ezzahar
# 3           ouazzani naaila
# 4               Saïd Khabba
# 5     ABDELGHANI BELLOUQUID
# 6   Soulaimani Abderrahmane
# 7            GHOULAM Cherki
# 8            Yedir Ouhdouch
# 9      El Modafar cherkaoui
# 10            Allal Barroug
# 11        Abdellatif Hafidi
# 12         Lahoucine HANICH
# 13    Mohammadine EL HADDAD
# 14          Abdelaziz Abbad
# 15           Mohamed Bennis
# 16               M. Hajjaji
# 17          Brahim Benhamou
# 18            Lahcen Maniar
# 19             AZIZ Faissal
#
#                                      ASS - Unevercity  \
# 0     ProcEDE- FST de Marrakech,Université Cadi Ayyad
# 1                               Université Cadi Ayyad
# 2   MISCOM, ENSA Safi,Université Cadi Ayyad Marrakech
# 3     professeur à l'université Cadi Ayyad, Marrakech
# 4               Professeur de l'Université Cadi Ayyad
# 5    professeur de mathématique,université cadi ayyad
# 6   Professor,Cadi Ayyad University, Marrakech, Mo...
# 7   Faculty of Sciences and Techniques,Cadi Ayyad ...
# 8   professeur de microbiologieUniversité Cadi  Ayyad
# 9        Professeur de Biologie,Université Cadi Ayyad
# 10      Professor -Cadi Ayyad University  - Marrakech
# 11                              CADI AYYAD UNIVERSITY
# 12  Professeur d'Hydrogéologie, Faculté des Scienc...
# 13                              Université Cadi Ayyad
# 14  Faculty of Sciences, Semlalia,Cadi Ayyad Unive...
# 15                              Université Cadi Ayyad
# 16                        Prof.,Université Cadi Ayyad
# 17  Cadi Ayyad University Marrakech, Physics-Therm...
# 18                    Université Cadi Ayyad Marrakech
# 19                              Cadi Ayyad University
#
#                                             Spciality H indice global  \
# 0   physique, irrigation, Agricultural Sciences, r...              37
# 1                Energies renouvelables, PV, Stockage              29
# 2   Land-atmosphere interactions, Soil Moisture, R...              28
# 3                      Wastewater treatment and reuse              31
# 4   Ressources en eau, Besoin en eau des cultures,...              32
# 5   modélisation des systèmes complexes et analyse...              28
# 6                       Tectonic and Regional Geology              29
# 7                                     Agrophysiologie              29
# 8   Actinobactéries, biotechnologie microbienne, s...              25
# 9                            Biotechnologies végétles              31
# 10  Apatites, Calcium Phosphates, Adsorption, Drug...              27
# 11  Lipids quality and technology, Membrane separa...              25
# 12    Hydrogéologie, télédétection, Hydrologie nivale              29
# 13  adsorption  décontamination plan d'expérience DFT              26
# 14  Valorization and Conservation of Medicinal and...              28
# 15                                                                 23
# 16  Materials science, traditional ceramics, clays...              23
# 17  Energy Efficiency in Buildings, Heat and Mass ...              21
# 18  Control theory: controllability and stabilization              20
# 19  Water treatment, biomaterials, nanocomposites,...              21
#
#    Citations global H indice_I10 global H indice depuis 2018  \
# 0              5231                  69                   34
# 1              3973                 105                   22
# 2              3703                  46                   26
# 3              3549                  72                   26
# 4              3474                  65                   28
# 5              3362                  43                   16
# 6              3322                  52                   25
# 7              3213                  49                   22
# 8              3007                  46                   20
# 9              2963                  77                   25
# 10             2806                  37                   18
# 11             2686                  40                   23
# 12             2560                  52                   25
# 13             2525                  51                   24
# 14             2506                  56                   23
# 15             1909                  55                   18
# 16             1763                  42                   18
# 17             1570                  36                   17
# 18             1449                  45                   14
# 19             1417                  39                   21
#
#    Citations depuis 2018 H indice_I10 depuis 2018  Article  \
# 0                   3308                       63       20
# 1                   1899                       66       20
# 2                   2399                       41       20
# 3                   2502                       60       20
# 4                   2490                       53       20
# 5                   1571                       23       20
# 6                   2041                       44       20
# 7                   1858                       43       20
# 8                   1875                       40       20
# 9                   2052                       58       20
# 10                   899                       25       20
# 11                  1693                       31       20
# 12                  1928                       45       20
# 13                  1785                       41       20
# 14                  1627                       47       20
# 15                  1196                       31       20
# 16                   992                       30       20
# 17                  1103                       29       20
# 18                   679                       25       20
# 19                  1349                       37       20
#
#                                               faculty
# 0                                                FSTG
# 1                                               Other
# 2                                                ENSA
# 3     professeur à l'université Cadi Ayyad, Marrakech
# 4               Professeur de l'Université Cadi Ayyad
# 5    professeur de mathématique,université cadi ayyad
# 6   Professor,Cadi Ayyad University, Marrakech, Mo...
# 7                                                FSTG
# 8   professeur de microbiologieUniversité Cadi  Ayyad
# 9        Professeur de Biologie,Université Cadi Ayyad
# 10      Professor -Cadi Ayyad University  - Marrakech
# 11                                              Other
# 12                                               FSTG
# 13                                              Other
# 14                                               FSSM
# 15                                              Other
# 16                        Prof.,Université Cadi Ayyad
# 17  Cadi Ayyad University Marrakech, Physics-Therm...
# 18                    Université Cadi Ayyad Marrakech
# 19                              Cadi Ayyad University

# %% [markdown]
# # Transform Article Data

# %%
articles = [article for item in articles_data for article in item["Article"]]
pd.DataFrame(articles)
# Out:
#                                            Nom Article  \
# 0    Evapotranspiration components determined by st...
# 1    Monitoring wheat phenology and irrigation in C...
# 2    Combining FAO-56 model and ground-based remote...
# 3    The use of high‐resolution image time series f...
# 4    Performance assessment of AquaCrop model for e...
# ..                                                 ...
# 395  Characteristics of cellulose microfibers and n...
# 396  Engineering of highly Brachychiton populneus s...
# 397  Pathogens evolution during the composting of t...
# 398  Can the application of graphene oxide contribu...
# 399  Therapeutic potential of polyphenols in the ma...
#
#                                            description  \
# 0    Agricultural and forest meteorology 125 (3-4),...
# 1     Agricultural Water Management 79 (1), 1-27, 2006
# 2    Agricultural water management 87 (1), 41-54, 2007
# 3    International Journal of Remote Sensing 29 (1)...
# 4     Agricultural Water Management 163, 219-235, 2016
# ..                                                 ...
# 395                      Cellulose 28, 4089-4103, 2021
# 396     Journal of Molecular Liquids 346, 117092, 2022
# 397  Waste and Biomass Valorization 11, 1789-1797, ...
# 398  Current Research in Pharmacology and Drug Disc...
# 399  Evidence-Based Complementary and Alternative M...
#
#                                                 auteur Annee cite par
# 0    DG Williams, W Cable, K Hultine, JCB Hoedjes, ...  2004      570
# 1    VS B. Duchemin, R. Hadria, S. Er-raki, G. Boul...  2006      515
# 2    S Er-Raki, A Chehbouni, N Guemouria, B Duchemi...  2007      328
# 3    V Simonneaux, B Duchemin, D Helson, S Er‐Raki,...  2008      238
# 4    J Toumi, S Er-Raki, J Ezzahar, S Khabba, L Jar...  2016      161
# ..                                                 ...   ...      ...
# 395  A Bahloul, Z Kassab, F Aziz, H Hannache, R Bou...  2021       24
# 396        K Aziz, F Aziz, R Mamouni, L Aziz, N Saffaj  2022       23
# 397  K Atif, A Haouas, F Aziz, MY Jamali, A Tallou,...  2020       22
# 398  LGMSUAF Asmaa Rhazouani, Khalid Aziz, Halima G...  2021       21
# 399  MT Kabir, N Tabassum, MS Uddin, F Aziz, T Behl...  2021       21
#
# [400 rows x 5 columns]

# %%
def decompose_description(description):
    # print(description)
    first_digit_index = next((i for i, c in enumerate(description) if c.isdigit()), None)

    article_revue = description[:first_digit_index].strip()
    remaining_info = description[first_digit_index:].strip()

    components = [item.strip() for item in remaining_info.split(',')]
    # print(components)
    volume_number = ""
    year = ""
    pages = ""
    volume = ""
    number = ""
    # Extracting values
    if len(components) == 1:
        year = components[0]
    else:
        volume_number = components[0]
        if len(components)>2:
            pages = components[1]
            year = components[2]
        else:
            pages = ""
            year = components[1]

    # Further splitting volume and number
    if volume_number != "":
        volume_number_ = [part.strip() for part in volume_number.split('(')]
        if len(volume_number_) > 1:
            volume, number = [part.strip() for part in volume_number.split('(')]
        else:
            volume = volume_number_[0]
            number = ""
    return {
        'Revue': article_revue,
        'Volume': volume,
        'Number': number.replace(")", ""),
        'Pages': pages,
        'Year': year,
    }

def decompose_articles(articles):
    articles_decomposed = []
    for article in articles:
            desc = article["description"]
            information = decompose_description(desc)
            author_data = {
                "Article_Title": article["Nom Article"],
                #"Author": author,
                "Year": article["Annee"],
                "Description": desc,
                'Revue': information['Revue'],
                'Volume': re.sub(r'\D', '', information['Volume'].replace(" …", "")),
                #'Volume': information['Volume'].replace(" …", ""),
                'Number': re.sub(r'\D', '', information['Number']),
                #'Number': information['Number'].replace(r"\w+", ""),
                'Pages': re.sub(r'\D', '', information['Pages']),
                #'Pages': information['Pages'],
            }
            articles_decomposed.append(author_data)
    return articles_decomposed

# %%
articles_v2 = decompose_articles(articles)
articles_v2_df = pd.DataFrame(articles_v2)
columns_to_replace = ['Number', 'Volume', 'Pages']
articles_v2_df[columns_to_replace] = articles_v2_df[columns_to_replace].fillna(0)
articles_v2

# %%
articles_v2_df.to_csv('generated/article_unique_v2.csv', index=False)
