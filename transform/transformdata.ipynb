# %%
import json
import pandas as pd

# %%
with open("uca.json", 'r') as file:
    data = json.load(file)

# %%
class Transform:
    def __init__(self, to, test) -> None:
        self.value = to
        self.test = test

def test(e, search):
    return any(s.lower() in e.lower() for s in search)

def transform_to_fstg(e):
    return test(e, ["FST", "FSTG", "Faculty of Sciences and Techniques"])

def transform_to_ensa(e):
    return test(e, ["ENSA"])

def transform_to_other(e):
    return e == "Université Cadi Ayyad"

# def transform_to_other(e):
#     return test(e, ["Université Cadi Ayyad", "Cadi Ayyad University", " Cadi  Ayyad"])

faculties_transform = [
    Transform("FSTG", transform_to_fstg),
    Transform("ENSA", transform_to_ensa),
    Transform("Other", transform_to_other),
]

# %%
# create articles table
for ind, item in enumerate(data):
    for transform in faculties_transform:
        if transform.test(item["ASS - Unevercity"]):
            data[ind]["ASS - Unevercity"] = transform.value
            break
        
pd.DataFrame(data)
# Out:
#               Nom et Prénom  \
# 0             salah er-raki
# 1     Abdelkader Outzourhit
# 2             Jamal Ezzahar
# 3           ouazzani naaila
# 4               Saïd Khabba
# 5     ABDELGHANI BELLOUQUID
# 6   Soulaimani Abderrahmane
# 7            GHOULAM Cherki
# 8            Yedir Ouhdouch
# 9      El Modafar cherkaoui
# 10            salah er-raki
# 11    Abdelkader Outzourhit
# 12            Jamal Ezzahar
# 13          ouazzani naaila
# 14              Saïd Khabba
# 15    ABDELGHANI BELLOUQUID
# 16  Soulaimani Abderrahmane
# 17           GHOULAM Cherki
# 18           Yedir Ouhdouch
# 19     El Modafar cherkaoui
#
#                                      ASS - Unevercity  \
# 0                                                FSTG
# 1                                               Other
# 2                                                ENSA
# 3     professeur à l'université Cadi Ayyad, Marrakech
# 4               Professeur de l'Université Cadi Ayyad
# 5    professeur de mathématique,université cadi ayyad
# 6   Professor,Cadi Ayyad University, Marrakech, Mo...
# 7                                                FSTG
# 8   professeur de microbiologieUniversité Cadi  Ayyad
# 9        Professeur de Biologie,Université Cadi Ayyad
# 10                                               FSTG
# 11                                              Other
# 12                                               ENSA
# 13    professeur à l'université Cadi Ayyad, Marrakech
# 14              Professeur de l'Université Cadi Ayyad
# 15   professeur de mathématique,université cadi ayyad
# 16  Professor,Cadi Ayyad University, Marrakech, Mo...
# 17                                               FSTG
# 18  professeur de microbiologieUniversité Cadi  Ayyad
# 19       Professeur de Biologie,Université Cadi Ayyad
#
#                                             Spciality H indice depuis 2018  \
# 0   physiqueirrigationAgricultural Sciencesremote ...                   37
# 1                    Energies renouvelablesPVStockage                   29
# 2   Land-atmosphere interactionsSoil MoistureRemot...                   28
# 3                      Wastewater treatment and reuse                   31
# 4   Ressources en eauBesoin en eau des culturesmod...                   32
# 5   modélisation des systèmes complexes et analyse...                   28
# 6                       Tectonic and Regional Geology                   29
# 7                                     Agrophysiologie                   29
# 8   Actinobactériesbiotechnologie microbiennesolub...                   25
# 9                            Biotechnologies végétles                   31
# 10  physiqueirrigationAgricultural Sciencesremote ...                   37
# 11                   Energies renouvelablesPVStockage                   29
# 12  Land-atmosphere interactionsSoil MoistureRemot...                   28
# 13                     Wastewater treatment and reuse                   31
# 14  Ressources en eauBesoin en eau des culturesmod...                   32
# 15  modélisation des systèmes complexes et analyse...                   28
# 16                      Tectonic and Regional Geology                   29
# 17                                    Agrophysiologie                   29
# 18  Actinobactériesbiotechnologie microbiennesolub...                   25
# 19                           Biotechnologies végétles                   31
#
#    Citations depuis 2018 H indice_I10 depuis 2018 H indice global  \
# 0                   5231                       37              34
# 1                   3973                       29              22
# 2                   3703                       28              26
# 3                   3549                       31              26
# 4                   3474                       32              28
# 5                   3362                       28              16
# 6                   3322                       29              25
# 7                   3213                       29              22
# 8                   3007                       25              20
# 9                   2963                       31              25
# 10                  5231                       37              34
# 11                  3973                       29              22
# 12                  3703                       28              26
# 13                  3549                       31              26
# 14                  3474                       32              28
# 15                  3362                       28              16
# 16                  3322                       29              25
# 17                  3213                       29              22
# 18                  3007                       25              20
# 19                  2963                       31              25
#
#    Citations global H indice_I10 global  \
# 0              3308                  63
# 1              1899                  66
# 2              2399                  41
# 3              2502                  60
# 4              2490                  53
# 5              1571                  23
# 6              2041                  44
# 7              1858                  43
# 8              1875                  40
# 9              2052                  58
# 10             3308                  63
# 11             1899                  66
# 12             2399                  41
# 13             2502                  60
# 14             2490                  53
# 15             1571                  23
# 16             2041                  44
# 17             1858                  43
# 18             1875                  40
# 19             2052                  58
#
#                                               Article
# 0   [{'Nom Article': 'Evapotranspiration component...
# 1   [{'Nom Article': 'Preparation and characteriza...
# 2   [{'Nom Article': 'Monitoring wheat phenology a...
# 3   [{'Nom Article': 'Low cost biosorbent “banana ...
# 4   [{'Nom Article': 'Monitoring wheat phenology a...
# 5   [{'Nom Article': 'Toward a mathematical theory...
# 6   [{'Nom Article': 'The south-western branch of ...
# 7   [{'Nom Article': 'Effects of salt stress on gr...
# 8   [{'Nom Article': 'Rock phosphate-solubilizing ...
# 9   [{'Nom Article': 'Genetic structure and core c...
# 10  [{'Nom Article': 'Evapotranspiration component...
# 11  [{'Nom Article': 'Preparation and characteriza...
# 12  [{'Nom Article': 'Monitoring wheat phenology a...
# 13  [{'Nom Article': 'Low cost biosorbent “banana ...
# 14  [{'Nom Article': 'Monitoring wheat phenology a...
# 15  [{'Nom Article': 'Toward a mathematical theory...
# 16  [{'Nom Article': 'The south-western branch of ...
# 17  [{'Nom Article': 'Effects of salt stress on gr...
# 18  [{'Nom Article': 'Rock phosphate-solubilizing ...
# 19  [{'Nom Article': 'Genetic structure and core c...

# %%
# create profiles table
profiles = [item.copy() | {"Article": len(item["Article"])} for item in data]
df = pd.DataFrame(profiles)
df.to_excel('profiles.xlsx', index=False)

# %%
# create articles table
articles = [article  | {"Author": item["Nom et Pr\u00e9nom"]} for item in data for article in item["Article"]]
print(articles[0])
df = pd.DataFrame(articles)
df.to_excel('articles.xlsx', index=False)
# Out:
# {'Nom Article': 'Evapotranspiration components determined by stable isotope, sap flow and eddy covariance techniques', 'description': 'Agricultural and forest meteorology 125 (3-4), 241-258, 2004', 'auteur': 'DG Williams, W Cable, K Hultine, JCB Hoedjes, EA Yepez, V Simonneaux, ...', 'Annee': '2004', 'Author': 'salah er-raki'}

# %%
# create articles table
faculties = [item["ASS - Unevercity"] for item in data]
for i, f in enumerate(faculties):
    for transform in faculties_transform:
        if transform.test(f):
            faculties[i] = transform.value
            break

df = pd.DataFrame(faculties)
df.to_excel('faculites.xlsx', index=False)
faculties
# Out:
# ['FSTG',
#  'Other',
#  'ENSA',
#  "professeur à l'université Cadi Ayyad, Marrakech",
#  "Professeur de l'Université Cadi Ayyad",
#  'professeur de mathématique,université cadi ayyad',
#  'Professor,Cadi Ayyad University, Marrakech, Morocco',
#  'FSTG',
#  'professeur de microbiologieUniversité Cadi  Ayyad',
#  'Professeur de Biologie,Université Cadi Ayyad',
#  'FSTG',
#  'Other',
#  'ENSA',
#  "professeur à l'université Cadi Ayyad, Marrakech",
#  "Professeur de l'Université Cadi Ayyad",
#  'professeur de mathématique,université cadi ayyad',
#  'Professor,Cadi Ayyad University, Marrakech, Morocco',
#  'FSTG',
#  'professeur de microbiologieUniversité Cadi  Ayyad',
#  'Professeur de Biologie,Université Cadi Ayyad']
